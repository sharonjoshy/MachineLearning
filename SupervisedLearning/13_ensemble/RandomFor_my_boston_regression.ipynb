# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.datasets import load_boston
from sklearn.tree import DecisionTreeRegressor

# %%
boston = load_boston()
boston_df=pd.DataFrame(boston.data,columns=boston.feature_names)
boston_df["Price"]=boston.target
boston_df.head()
# Out:
# c:\Users\sharo\anaconda2\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
boston_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
X=boston_df.drop(["Price"],axis=1)
y=boston_df["Price"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
dt_reg = DecisionTreeRegressor()   # data overfit aan 

dt_reg.fit(X_train,y_train)

sc=dt_reg.score(X_train,y_train)
print("R-squared Train",sc)

ss=dt_reg.score(X_test,y_test)
print("R-squared Test",ss)

y_pred = dt_reg.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE:",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train 1.0
# R-squared Test 0.8180301282507505
# MSE: 16.678355263157894
# RMSE : 4.083914208594237

# %%
from sklearn import tree

plt.figure(figsize=(15,10))

tree.plot_tree(dt_reg,filled=True,class_names=True)
plt.show()

# %%
dt_reg = DecisionTreeRegressor(max_depth=6)  #regression aaayath kond criterion illa mse aan ivide

dt_reg.fit(X_train,y_train)

sc=dt_reg.score(X_train,y_train)
print("R-squared Train",sc)

ss=dt_reg.score(X_test,y_test)
print("R-squared Test",ss)

y_pred = dt_reg.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE:",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train 0.9485651664023145
# R-squared Test 0.8142539820439644
# MSE: 17.024456006962282
# RMSE : 4.126070286236322

# %%
dt_reg = DecisionTreeRegressor(max_depth=7)  #regression aaayath kond criterion illa mse aan ivide

dt_reg.fit(X_train,y_train)

sc=dt_reg.score(X_train,y_train)
print("R-squared Train",sc)

ss=dt_reg.score(X_test,y_test)
print("R-squared Test",ss)

y_pred = dt_reg.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE:",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train 0.9723580808024771
# R-squared Test 0.824828749986965
# MSE: 16.055231074925995
# RMSE : 4.006897936674454

# %%
dt_reg = DecisionTreeRegressor(max_depth=8)  #regression aaayath kond criterion illa mse aan ivide

dt_reg.fit(X_train,y_train)

sc=dt_reg.score(X_train,y_train)
print("R-squared Train",sc)

ss=dt_reg.score(X_test,y_test)
print("R-squared Test",ss)

y_pred = dt_reg.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE:",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train 0.985593699118394
# R-squared Test 0.8435258953809268
# MSE: 14.341553803574635
# RMSE : 3.7870243996539865

# %%
dt_reg = DecisionTreeRegressor(max_depth=9)  #regression aaayath kond criterion illa mse aan ivide

dt_reg.fit(X_train,y_train)

sc=dt_reg.score(X_train,y_train)
print("R-squared Train",sc)

ss=dt_reg.score(X_test,y_test)
print("R-squared Test",ss)

y_pred = dt_reg.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE:",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train 0.9933935912917742
# R-squared Test 0.8136893410970931
# MSE: 17.076207883344438
# RMSE : 4.13233685501853

# %%
dt_reg = DecisionTreeRegressor(max_depth=4)  #regression aaayath kond criterion illa mse aan ivide

dt_reg.fit(X_train,y_train)

sc=dt_reg.score(X_train,y_train)
print("R-squared Train",sc)

ss=dt_reg.score(X_test,y_test)
print("R-squared Test",ss)

y_pred = dt_reg.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE:",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train 0.8857388736713648
# R-squared Test 0.8646893116543823
# MSE: 12.40183173970917
# RMSE : 3.521623452288613

# %%
# max_depth 4 kodukkumbozhanu apt aayittulla train and test r-squared value kittunnath

# %%
from sklearn import tree

plt.figure(figsize=(15,10))

tree.plot_tree(dt_reg,filled=True,class_names=True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)

sc=lr.score(X_train,y_train)
print(f"Train accuarcy for {lr.__class__.__name__} is {sc}")

sc=lr.score(X_test,y_test)
print(f"Test accuarcy for {lr.__class__.__name__} is {sc}")
# Out:
# Train accuarcy for LinearRegression is 0.7103879080674731
# Test accuarcy for LinearRegression is 0.7836295385076268

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestRegressor

clf=RandomForestRegressor()

clf.fit(X_train,y_train)

sc=clf.score(X_train,y_train)
print(f"Train accuarcy for {clf.__class__.__name__} is {sc}")

sc=clf.score(X_test,y_test)
print(f"Test accuarcy for {clf.__class__.__name__} is {sc}")
# Out:
# Train accuarcy for RandomForestRegressor is 0.980066884993085
# Test accuarcy for RandomForestRegressor is 0.9045977707013423

# %%
from sklearn.ensemble import GradientBoostingRegressor
clf=GradientBoostingRegressor()

clf.fit(X_train,y_train)

sc=clf.score(X_train,y_train)
print(f"Train accuarcy for {clf.__class__.__name__} is {sc}")

sc=clf.score(X_test,y_test)
print(f"Test accuarcy for {clf.__class__.__name__} is {sc}")

    
    
print("************************")
# Out:
# Train accuarcy for GradientBoostingRegressor is 0.9818725018961298
# Test accuarcy for GradientBoostingRegressor is 0.9227863965050656
# ************************
